# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob

csv_folder_file_path = r"C:\HLAG\Apps\Self_Learn_Workspace\Python_Natural_Language_processing_NAKPrep\PY Hausarbeit\HA_TextAnalytics\lens_org_data_files\*.csv"
all_csv_file_paths = glob.glob(csv_folder_file_path)

individual_dataframes = [pd.read_csv(file) for file in all_csv_file_paths]
print(len(individual_dataframes))
summarized_dataframe = pd.concat(individual_dataframes, ignore_index=True)

columnName = ("Source Country")

country_counts = summarized_dataframe[columnName].dropna().astype(str).value_counts()
# Out:
# C:\Users\SCHUPPT\AppData\Local\Temp\ipykernel_26368\1050635637.py:8: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   individual_dataframes = [pd.read_csv(file) for file in all_csv_file_paths]
# C:\Users\SCHUPPT\AppData\Local\Temp\ipykernel_26368\1050635637.py:8: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   individual_dataframes = [pd.read_csv(file) for file in all_csv_file_paths]
# C:\Users\SCHUPPT\AppData\Local\Temp\ipykernel_26368\1050635637.py:8: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   individual_dataframes = [pd.read_csv(file) for file in all_csv_file_paths]
# C:\Users\SCHUPPT\AppData\Local\Temp\ipykernel_26368\1050635637.py:8: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
high_volume_country_counts = country_counts[country_counts >= 500]

print(type(high_volume_country_counts))
print(high_volume_country_counts)

# Plot as a bar chart
plt.figure(figsize=(12, 6))
high_volume_country_counts.plot(kind='bar', color='skyblue', edgecolor='black')

# Customize the chart
plt.xlabel("Country", fontsize=12)
plt.ylabel("Number of Articles", fontsize=12)
plt.title("Number of Articles per Country", fontsize=14)
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()
# Out:
# <class 'pandas.core.series.Series'>
# Source Country
# United Kingdom               74567
# Netherlands                  54746
# United States                49317
# Germany                      39440
# Switzerland                  13475
# Russian Federation            9423
# China                         8387
# India                         3620
# South Korea                   3300
# Hungary                       2294
# Iran, Islamic Republic of     1439
# Egypt                         1370
# Turkey                        1164
# Saudi Arabia                   989
# Brazil                         950
# Japan                          840
# England                        830
# Indonesia                      629
# France                         574
# Italy                          563
# Name: count, dtype: int64
