# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob

csv_folder_file_path = r"C:\HLAG\Apps\Self_Learn_Workspace\Python_Natural_Language_processing_NAKPrep\PY Hausarbeit\HA_TextAnalytics\lens_org_data_files\*.csv"
all_csv_file_paths = glob.glob(csv_folder_file_path)

individual_dataframes = [pd.read_csv(file) for file in all_csv_file_paths]
summarized_dataframe = pd.concat(individual_dataframes, ignore_index=True)

columnName = ("Source Country")

country_counts = summarized_dataframe[columnName].dropna().astype(str).value_counts()
# Out:
# C:\Users\SCHUPPT\AppData\Local\Temp\ipykernel_3320\1902739724.py:8: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   individual_dataframes = [pd.read_csv(file) for file in all_csv_file_paths]
# C:\Users\SCHUPPT\AppData\Local\Temp\ipykernel_3320\1902739724.py:8: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   individual_dataframes = [pd.read_csv(file) for file in all_csv_file_paths]
# C:\Users\SCHUPPT\AppData\Local\Temp\ipykernel_3320\1902739724.py:8: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   individual_dataframes = [pd.read_csv(file) for file in all_csv_file_paths]
# C:\Users\SCHUPPT\AppData\Local\Temp\ipykernel_3320\1902739724.py:8: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   individual_dataframes = [pd.read_csv(file) for file in all_csv_file_paths]
# ...

# %%
high_volume_country_counts = country_counts.nlargest(15)

print(high_volume_country_counts)
print(len(high_volume_country_counts))

# Plot as a bar chart
plt.figure(figsize=(12, 6))
high_volume_country_counts.plot(kind='bar', color='skyblue', edgecolor='black')

# Customize the chart
plt.xlabel("Land", fontsize=12)
plt.ylabel("Anzahl wissenschaftlicher Publikationen", fontsize=12)
plt.title("Anzahl wissenschaftlicher Publikationen pro Land", fontsize=14)
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()
# Out:
# Source Country
# United Kingdom               74567
# Netherlands                  54746
# United States                49317
# Germany                      39440
# Switzerland                  13475
# Russian Federation            9423
# China                         8387
# India                         3620
# South Korea                   3300
# Hungary                       2294
# Iran, Islamic Republic of     1439
# Egypt                         1370
# Turkey                        1164
# Saudi Arabia                   989
# Brazil                         950
# Name: count, dtype: int64
# 15

# %%
#Im obigen Ergebnis gibt es sehr starke Top 5. Hier sollen noch einmal die Ländern unterhalb der top 5 besser zur Geltung kommen.
#Daher werden die Top 5 (oberhalb 10000) ausgeschlossen und dann das Diagramm wiederholt
lower_volume_country_counts = country_counts[country_counts <= 20000].nlargest(12)
plt.figure(figsize=(12, 6))
lower_volume_country_counts.plot(kind='bar', color='skyblue', edgecolor='black')

# Customize the chart
plt.xlabel("Land", fontsize=12)
plt.ylabel("Anzahl wissenschaftlicher Publikationen", fontsize=12)
plt.title("Anzahl wissenschaftlicher Publikationen pro Land", fontsize=14)
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# Analyse einzelner Jahre für den Verlauf.
# Stichproben über 2015 (Anfang), 2020 (Mitte) und 2024 (letztes vollständiges Jahr)

# %%
csv_file_path_2015 = "C:\HLAG\Apps\Self_Learn_Workspace\Python_Natural_Language_processing_NAKPrep\PY Hausarbeit\HA_TextAnalytics\lens_org_data_files\solar-energy-articles-2015.csv"
df_2015 = pd.read_csv(csv_file_path_2015)

country_counts_2015 = df_2015[columnName].dropna().astype(str).value_counts().nlargest(30)

plt.figure(figsize=(20, 6))
country_counts_2015.plot(kind='bar', color='skyblue', edgecolor='black')

# Customize the chart
plt.xlabel("Land", fontsize=12)
plt.ylabel("Anzahl wissenschaftlicher Publikationen", fontsize=12)
plt.title("Anzahl wissenschaftlicher Publikationen pro Land in 2015", fontsize=14)
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\H'
# <>:1: SyntaxWarning: invalid escape sequence '\H'
# C:\Users\SCHUPPT\AppData\Local\Temp\ipykernel_8572\2401195509.py:1: SyntaxWarning: invalid escape sequence '\H'
#   csv_file_path_2015 = "C:\HLAG\Apps\Self_Learn_Workspace\Python_Natural_Language_processing_NAKPrep\PY Hausarbeit\HA_TextAnalytics\lens_org_data_files\solar-energy-articles-2015.csv"

# %%
csv_file_path_2020_1 = "C:\HLAG\Apps\Self_Learn_Workspace\Python_Natural_Language_processing_NAKPrep\PY Hausarbeit\HA_TextAnalytics\lens_org_data_files\solar-energy-articles-2020-part-one.csv"
csv_file_path_2020_2 = "C:\HLAG\Apps\Self_Learn_Workspace\Python_Natural_Language_processing_NAKPrep\PY Hausarbeit\HA_TextAnalytics\lens_org_data_files\solar-energy-articles-2020-part-two.csv"

df_2020_1 = pd.read_csv(csv_file_path_2020_1)
df_2020_2 = pd.read_csv(csv_file_path_2020_2)

summarized_dataframe_2020 = pd.concat([df_2020_1, df_2020_2], ignore_index=True)

country_counts_2020 = summarized_dataframe_2020[columnName].dropna().astype(str).value_counts().nlargest(30)

plt.figure(figsize=(20, 6))
country_counts_2020.plot(kind='bar', color='skyblue', edgecolor='black')

# Customize the chart
plt.xlabel("Land", fontsize=12)
plt.ylabel("Anzahl wissenschaftlicher Publikationen", fontsize=12)
plt.title("Anzahl wissenschaftlicher Publikationen pro Land in 2020", fontsize=14)
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\H'
# <>:2: SyntaxWarning: invalid escape sequence '\H'
# <>:1: SyntaxWarning: invalid escape sequence '\H'
# <>:2: SyntaxWarning: invalid escape sequence '\H'
# C:\Users\SCHUPPT\AppData\Local\Temp\ipykernel_8572\78263192.py:1: SyntaxWarning: invalid escape sequence '\H'
#   csv_file_path_2020_1 = "C:\HLAG\Apps\Self_Learn_Workspace\Python_Natural_Language_processing_NAKPrep\PY Hausarbeit\HA_TextAnalytics\lens_org_data_files\solar-energy-articles-2020-part-one.csv"
# C:\Users\SCHUPPT\AppData\Local\Temp\ipykernel_8572\78263192.py:2: SyntaxWarning: invalid escape sequence '\H'
#   csv_file_path_2020_2 = "C:\HLAG\Apps\Self_Learn_Workspace\Python_Natural_Language_processing_NAKPrep\PY Hausarbeit\HA_TextAnalytics\lens_org_data_files\solar-energy-articles-2020-part-two.csv"

# %%
csv_file_path_2024_1 = "C:\HLAG\Apps\Self_Learn_Workspace\Python_Natural_Language_processing_NAKPrep\PY Hausarbeit\HA_TextAnalytics\lens_org_data_files\solar-energy-articles-2024-part-one.csv"
csv_file_path_2024_2 = "C:\HLAG\Apps\Self_Learn_Workspace\Python_Natural_Language_processing_NAKPrep\PY Hausarbeit\HA_TextAnalytics\lens_org_data_files\solar-energy-articles-2024-part-two.csv"

df_2024_1 = pd.read_csv(csv_file_path_2024_1)
df_2024_2 = pd.read_csv(csv_file_path_2024_2)

summarized_dataframe_2024 = pd.concat([df_2024_1, df_2024_2], ignore_index=True)

country_counts_2024 = summarized_dataframe_2024[columnName].dropna().astype(str).value_counts().nlargest(30)

plt.figure(figsize=(20, 6))
country_counts_2024.plot(kind='bar', color='skyblue', edgecolor='black')

# Customize the chart
plt.xlabel("Land", fontsize=12)
plt.ylabel("Anzahl wissenschaftlicher Publikationen", fontsize=12)
plt.title("Anzahl wissenschaftlicher Publikationen pro Land in 2024", fontsize=14)
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\H'
# <>:2: SyntaxWarning: invalid escape sequence '\H'
# <>:1: SyntaxWarning: invalid escape sequence '\H'
# <>:2: SyntaxWarning: invalid escape sequence '\H'
# C:\Users\SCHUPPT\AppData\Local\Temp\ipykernel_8572\1321220367.py:1: SyntaxWarning: invalid escape sequence '\H'
#   csv_file_path_2024_1 = "C:\HLAG\Apps\Self_Learn_Workspace\Python_Natural_Language_processing_NAKPrep\PY Hausarbeit\HA_TextAnalytics\lens_org_data_files\solar-energy-articles-2024-part-one.csv"
# C:\Users\SCHUPPT\AppData\Local\Temp\ipykernel_8572\1321220367.py:2: SyntaxWarning: invalid escape sequence '\H'
#   csv_file_path_2024_2 = "C:\HLAG\Apps\Self_Learn_Workspace\Python_Natural_Language_processing_NAKPrep\PY Hausarbeit\HA_TextAnalytics\lens_org_data_files\solar-energy-articles-2024-part-two.csv"
# ...
